# %% [markdown]
# ## Exploration of the GTSDB dataset

# %%
import os
import cv2
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
# Load the training labels
root = 'data'
data = pd.read_csv(os.path.join(root, 'Train.csv'))

# Number of training samples (amount of samples in data)
num_samples = len(data)

# Show random data samples
import cv2
import numpy as np
import matplotlib.pyplot as plt

for ii in range(15):
    # Get random index
    idx = np.random.randint(0, num_samples)
    # Load image
    img = cv2.imread(os.path.join(root, data.iloc[idx]['Path']))
    # Convert image to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Show image
    plt.subplot(3, 5, ii + 1), plt.imshow(img), plt.title(data.iloc[idx]['ClassId'])
plt.show()

# %%
# Extract class identifiers
# Hint: Check the csv 
# Extract class identifiers
ids = data['ClassId'].values

# %%
from collections import Counter
hist = Counter(ids)

plt.bar(hist.keys(), hist.values()), plt.grid(True)
plt.xlabel('Traffic Sign ID'), plt.ylabel('Counts')
# Out:
# (Text(0.5, 0, 'Traffic Sign ID'), Text(0, 0.5, 'Counts'))

# %%
# Load images and calculate their sizes
image_sizes = []
for idx, row in data.iterrows():
    img = cv2.imread(os.path.join(root, row['Path']))
    image_sizes.append(img.shape[:2])

# %%
# Calculate brightness of each image
image_brightness = []
for idx, row in data.iterrows():
    img = cv2.imread(os.path.join(root, row['Path']))
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    brightness = np.mean(gray_img)
    image_brightness.append(brightness)

# %%
# Calculate brightness of each image
image_brightness = []
for idx, row in data.iterrows():
    img = cv2.imread(os.path.join(root, row['Path']))
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    brightness = np.mean(gray_img)
    image_brightness.append(brightness)

# %%
# Plot histogram of image brightness
plt.figure(figsize=(10, 5))
plt.hist(image_brightness, bins=50, color='orange', edgecolor='black', alpha=0.7)
plt.title('Distribution of Image Brightness')
plt.xlabel('Brightness')
plt.ylabel('Frequency')
plt.show()
