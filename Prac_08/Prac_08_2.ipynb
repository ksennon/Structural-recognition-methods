# %% [markdown]
# ## Homework 2

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time
from tensorflow.keras.callbacks import EarlyStopping

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %%
# Load Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %%
# Data normalization
x_train = x_train.reshape(-1, 28, 28, 1) / 255.0
x_test = x_test.reshape(-1, 28, 28, 1) / 255.0

# Visualize random samples
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ..., 0], cmap='gray')  # Updated to grayscale
        plt.title(y_train[idx])
        cnt = cnt + 1

# %% [markdown]
# ### Model 1

# %%
# Define the baseline classifier
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = MaxPooling2D((2, 2))(net)
net = Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = MaxPooling2D((2, 2))(net)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()

# Compile the model
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with early stopping
epochs = 50
batch_size = 64
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, 
                    validation_data=(x_test, y_test), callbacks=[early_stopping])
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 128)               401536
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 421642 (1.61 MB)
# Trainable params: 421642 (1.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.4093 - accuracy: 0.8528 - val_loss: 0.3293 - val_accuracy: 0.8807
# Epoch 2/50
# 938/938 [==============================] - 35s 37ms/step - loss: 0.2741 - accuracy: 0.9018 - val_loss: 0.2797 - val_accuracy: 0.8983
# Epoch 3/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.2388 - accuracy: 0.9130 - val_loss: 0.2609 - val_accuracy: 0.9078
# Epoch 4/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.2116 - accuracy: 0.9226 - val_loss: 0.2432 - val_accuracy: 0.9144
# Epoch 5/50
# 938/938 [==============================] - 54s 58ms/step - loss: 0.1924 - accuracy: 0.9291 - val_loss: 0.2542 - val_accuracy: 0.9104
# Epoch 6/50
# 938/938 [==============================] - 42s 45ms/step - loss: 0.1759 - accuracy: 0.9356 - val_loss: 0.2374 - val_accuracy: 0.9144
# Epoch 7/50
# 938/938 [==============================] - 38s 41ms/step - loss: 0.1621 - accuracy: 0.9407 - val_loss: 0.2541 - val_accuracy: 0.9165
# Epoch 8/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.1500 - accuracy: 0.9458 - val_loss: 0.2514 - val_accuracy: 0.9161
# Epoch 9/50
# 938/938 [==============================] - 36s 39ms/step - loss: 0.1380 - accuracy: 0.9493 - val_loss: 0.2577 - val_accuracy: 0.9150
# Epoch 10/50
# 938/938 [==============================] - 62s 67ms/step - loss: 0.1283 - accuracy: 0.9538 - val_loss: 0.2721 - val_accuracy: 0.9096
# Epoch 11/50
# 938/938 [==============================] - 37s 39ms/step - loss: 0.1192 - accuracy: 0.9561 - val_loss: 0.2863 - val_accuracy: 0.9125

# %%
# Plot training history
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])

plot_history(history)
# Out:
# Train Acc      0.9561333060264587
# Validation Acc 0.9125000238418579

# %% [markdown]
# ### Model 2

# %%
# Modify the baseline classifier to reduce overfitting
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = MaxPooling2D((2, 2))(net)
net = Dropout(0.5)(net)  # Add Dropout
net = Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = MaxPooling2D((2, 2))(net)
net = Flatten()(net)
net = Dense(128)(net)
net = BatchNormalization()(net)  # Add Batch Normalization
outputs = Dense(num_classes, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the network
epochs = 50
batch_size = 64

# Convert labels to one-hot encoding
y_train_one_hot = tf.keras.utils.to_categorical(y_train, num_classes)
y_test_one_hot = tf.keras.utils.to_categorical(y_test, num_classes)

history = model.fit(x_train, y_train_one_hot, batch_size=batch_size, epochs=epochs, 
                    validation_data=(x_test, y_test_one_hot), callbacks=[early_stopping])

plot_history(history)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_8 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_9 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 3136)              0
#
#  dense_8 (Dense)             (None, 128)               401536
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_9 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 422154 (1.61 MB)
# Trainable params: 421898 (1.61 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
